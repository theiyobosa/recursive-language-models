# %%
c = 5

# %%
def run():
    global c 
    c = 10

run()

# %%
print(c)
# Out:
# 10

# %%
locals()['c']
# Out:
# 10

# %%
globals()['c']
# Out:
# 10

# %%
__final_answer__ = None

def FINAL(answer):
    global __final_answer__
    __final_answer__ = answer

def FINAL_VAR(variable_name):
    global __final_answer__
    __final_answer__ = globals()[variable_name]

# %%
print(FINAL)
# Out:
# <function FINAL at 0x10a68adc0>
